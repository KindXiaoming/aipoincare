# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import os
from sklearn.decomposition import PCA
import torch.optim as optim
import copy

seed = 0
torch.manual_seed(seed)
np.random.seed(seed)

# %%
def train(session):
    
    #<--------------Pass Parameters-------------->
    prepcaremove = session['prepca']
    noise_threshold = float(session['noise_threshold'])
    nn_widths = list(eval(session['hidden_widths']))
    slope = float(session['slope'])
    L = eval(session['L'])
    opt = session['opt']
    lr = float(session['learning_rate'])
    batch_size = int(session['batch_size'])
    epoch = int(session['training_iteration'])
    a = float(session['a'])
    model = session['model']
    n_walk = int(session['n_walk'])
    
    #<--------------Load data-------------->
    xs = np.loadtxt("./data/"+model)
    n_train = xs.shape[0]
    input_dim = xs.shape[1]
    nn_widths.insert(0, input_dim)
    nn_widths.append(input_dim)
    
    #<--------------Preprocessing-------------->
    # step 1: normalize each dimension
    xs = (xs - np.mean(xs, axis=0)[np.newaxis,:])/np.std(xs, axis=0)[np.newaxis,:]
    # step 2: PCA (only rotation, no scaling)
    pca = PCA()
    xs = pca.fit_transform(xs)
    # step 3: normalize or remove dimension
    if prepcaremove == "yes":
        xs = xs/(np.std(xs,axis=0)[np.newaxis,:]+noise_threshold)
    else:
        input_dim = np.sum(pca.explained_variance_ratio_>noise_threshold)
        xs = xs[:,:input_dim]
        xs = xs/(np.std(xs,axis=0)[np.newaxis,:])
        
    #<--------------Build Networks-------------->
    class den(nn.Module):
        def __init__(self):
            super(den, self).__init__()
            self.linears = nn.ModuleList([nn.Linear(nn_widths[i], nn_widths[i+1]) for i in range(hidden_depth+1)])

        def forward(self, x):
            act = nn.LeakyReLU(slope)
            self.x = x
            for i in range(hidden_depth):
                self.x = act(self.linears[i](self.x))
            self.x = self.linears[hidden_depth](self.x)
            return self.x
    
    #<--------------Training------------->
    exps = []
    losses = []

    for sigmal in sigmals:
        den_net = den()
        criterion = nn.MSELoss()
        if opt == "Adam":
            optimizer = optim.Adam(den_net.parameters(), lr = lr)
        else:
            optimizer = optim.SGD(den_net.parameters(), lr = lr)
        print("sigmal={}".format(sigmal))

        for j in range(epoch):
            den_net.train()
            optimizer.zero_grad()
            choices = np.random.choice(n_train, batch_size)
            perturb = torch.normal(0,sigmal,size=(batch_size,input_dim))
            inputs0 = torch.tensor(xs[choices], dtype=torch.float) + perturb
            outputs = den_net(inputs0)
            loss = criterion(outputs, -perturb)
            loss.backward()
            optimizer.step()
            losses.append(float(loss.data))

            if j%log == 0:
                print('Epoch:  %d | Train: %.3g' %(j, loss))

        x0 = copy.deepcopy(xs[int(n_train/2)])
        x0 = x0[np.newaxis,:]

        x0 = x0 + np.random.randn(n_walk,input_dim) * sigmal
        x0 = x0 + den_net(torch.tensor(x0,dtype=torch.float)).detach().numpy()

        pca = PCA()
        pca.fit(x0)
        svs = pca.singular_values_
        exp_ratio = svs**2/np.sum(svs**2)
        exps.append(exp_ratio)

        torch.save(den_net.state_dict(), "./models/%.3f"%sigmal)

    exps = np.array(exps)
    
    #<--------------Plotting------------->
    # ERD
    def f(x,a=2):
        n = x.shape[1]
        mask = x < 1/(a*n)
        return np.sum(np.cos(np.pi/2*n*a*x)*mask,axis=1)
    
    ax1 = plt.figure(figsize=(7,5))
    exps = np.array(exps)
    for i in range(input_dim):
        plt.plot(sigmals, exps[:,i], marker="o")
    plt.xscale('log')
    plt.xlabel(r"$L$",fontsize=25)
    plt.ylabel("Explained Ratio",fontsize=25)

    ax2 = ax1.gca().twinx()
    ax2.plot(sigmals, f(exps,a=2), marker="o",color="red",linewidth=5, ls="--", markersize=15)
    plt.ylabel(r"$n_{eff}$",fontsize=25,color="red")

    plt.savefig('./plot/ERD_{}.png'.format(model),bbox_inches="tight")
    plt.show()
    
    # Neff histogram
    den_nets = []
    for j in range(sigmals.shape[0]):
        sigmal = sigmals[j]
        den_net = den()
        den_net.load_state_dict(torch.load("./models/%.3f"%sigmal))
        den_nets.append(copy.deepcopy(den_net))
        
    exp_ratioss = []
    npoint = 100

    for i in range(npoint):
        if i % 20 == 0:
            print(i)
        iid = np.random.choice(n_train)
        x0 = copy.deepcopy(xs[iid])
        x0 = x0[np.newaxis,:]

        exp_ratios = []

        for j in range(sigmals.shape[0]):

            x0 = x0 + np.random.randn(n_walk,input_dim) * sigmals[j]
            x0 = x0 + den_nets[j](torch.tensor(x0,dtype=torch.float)).detach().numpy()

            pca = PCA()
            pca.fit(x0)
            svs = pca.singular_values_
            exp_ratio = svs**2/np.sum(svs**2)
            exp_ratios.append(exp_ratio)
        exp_ratioss.append(exp_ratios)
    exp_ratioss = np.array(exp_ratioss)
    
    a = np.max(f(exp_ratioss.reshape(-1,input_dim)).reshape(npoint, sigmals.shape[0]),axis=1)
    plt.hist(a,bins=25)
    plt.xlabel(r"$n_{eff}$",fontsize=20)
    plt.ylabel("Count",fontsize=20)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.savefig('./plot/Neff_{}.png'.format(model),bbox_inches="tight")
    plt.show()

# %%
train(session)
# Out:
# sigmal=0.01
# Epoch:  0 | Train: 0.0515
# Epoch:  200 | Train: 9.61e-05
# Epoch:  400 | Train: 0.000101
# Epoch:  600 | Train: 9.69e-05
# Epoch:  800 | Train: 0.000111
# Epoch:  1000 | Train: 9.77e-05
# Epoch:  1200 | Train: 9.05e-05
# Epoch:  1400 | Train: 8.7e-05
# Epoch:  1600 | Train: 8.9e-05
# Epoch:  1800 | Train: 7.54e-05
# Epoch:  2000 | Train: 0.000114
# Epoch:  2200 | Train: 7.29e-05
# Epoch:  2400 | Train: 6.98e-05
# Epoch:  2600 | Train: 7.06e-05
# Epoch:  2800 | Train: 7.96e-05
# sigmal=0.02
# Epoch:  0 | Train: 0.0482
# Epoch:  200 | Train: 0.000378
# Epoch:  400 | Train: 0.000423
# Epoch:  600 | Train: 0.000327
# Epoch:  800 | Train: 0.000339
# Epoch:  1000 | Train: 0.00033
# Epoch:  1200 | Train: 0.000346
# Epoch:  1400 | Train: 0.000284
# Epoch:  1600 | Train: 0.000239
# Epoch:  1800 | Train: 0.000225
# Epoch:  2000 | Train: 0.000225
# Epoch:  2200 | Train: 0.000261
# Epoch:  2400 | Train: 0.000255
# Epoch:  2600 | Train: 0.000202
# Epoch:  2800 | Train: 0.000204
# sigmal=0.05
# Epoch:  0 | Train: 0.00769
# Epoch:  200 | Train: 0.00189
# Epoch:  400 | Train: 0.00144
# Epoch:  600 | Train: 0.00125
# Epoch:  800 | Train: 0.00134
# Epoch:  1000 | Train: 0.00153
# Epoch:  1200 | Train: 0.00137
# Epoch:  1400 | Train: 0.00123
# Epoch:  1600 | Train: 0.00119
# Epoch:  1800 | Train: 0.00123
# Epoch:  2000 | Train: 0.00126
# Epoch:  2200 | Train: 0.0013
# Epoch:  2400 | Train: 0.00163
# Epoch:  2600 | Train: 0.00158
# Epoch:  2800 | Train: 0.00135
# sigmal=0.1
# Epoch:  0 | Train: 0.038
# Epoch:  200 | Train: 0.0046
# Epoch:  400 | Train: 0.00518
# Epoch:  600 | Train: 0.00518
# Epoch:  800 | Train: 0.00581
# Epoch:  1000 | Train: 0.00623
# Epoch:  1200 | Train: 0.00585
# Epoch:  1400 | Train: 0.00663
# Epoch:  1600 | Train: 0.00544
# Epoch:  1800 | Train: 0.00516
# Epoch:  2000 | Train: 0.00579
# Epoch:  2200 | Train: 0.00579
# Epoch:  2400 | Train: 0.00545
# Epoch:  2600 | Train: 0.00501
# Epoch:  2800 | Train: 0.0048
# sigmal=0.2
# Epoch:  0 | Train: 0.0415
# Epoch:  200 | Train: 0.021
# Epoch:  400 | Train: 0.0193
# Epoch:  600 | Train: 0.0211
# Epoch:  800 | Train: 0.0191
# Epoch:  1000 | Train: 0.02
# Epoch:  1200 | Train: 0.0237
# Epoch:  1400 | Train: 0.0199
# Epoch:  1600 | Train: 0.0211
# Epoch:  1800 | Train: 0.0151
# Epoch:  2000 | Train: 0.0213
# Epoch:  2200 | Train: 0.0161
# Epoch:  2400 | Train: 0.019
# Epoch:  2600 | Train: 0.0162
# Epoch:  2800 | Train: 0.019
# sigmal=0.5
# Epoch:  0 | Train: 0.274
# Epoch:  200 | Train: 0.142
# Epoch:  400 | Train: 0.152
# Epoch:  600 | Train: 0.158
# Epoch:  800 | Train: 0.121
# Epoch:  1000 | Train: 0.136
# Epoch:  1200 | Train: 0.145
# Epoch:  1400 | Train: 0.138
# Epoch:  1600 | Train: 0.144
# Epoch:  1800 | Train: 0.159
# Epoch:  2000 | Train: 0.126
# Epoch:  2200 | Train: 0.141
# Epoch:  2400 | Train: 0.141
# Epoch:  2600 | Train: 0.123
# Epoch:  2800 | Train: 0.144
# sigmal=1.0
# Epoch:  0 | Train: 1.23
# Epoch:  200 | Train: 0.508
# Epoch:  400 | Train: 0.527
# Epoch:  600 | Train: 0.429
# Epoch:  800 | Train: 0.519
# Epoch:  1000 | Train: 0.4
# Epoch:  1200 | Train: 0.492
# Epoch:  1400 | Train: 0.491
# Epoch:  1600 | Train: 0.424
# Epoch:  1800 | Train: 0.438
# Epoch:  2000 | Train: 0.513
# Epoch:  2200 | Train: 0.534
# Epoch:  2400 | Train: 0.446
# Epoch:  2600 | Train: 0.484
# Epoch:  2800 | Train: 0.449
# sigmal=2.0
# Epoch:  0 | Train: 4.05
# Epoch:  200 | Train: 0.798
# Epoch:  400 | Train: 0.908
# Epoch:  600 | Train: 0.813
# Epoch:  800 | Train: 0.833
# Epoch:  1000 | Train: 0.794
# Epoch:  1200 | Train: 0.722
# Epoch:  1400 | Train: 0.833
# Epoch:  1600 | Train: 0.839
# Epoch:  1800 | Train: 0.819
# Epoch:  2000 | Train: 0.759
# Epoch:  2200 | Train: 0.837
# Epoch:  2400 | Train: 0.881
# Epoch:  2600 | Train: 0.875
# Epoch:  2800 | Train: 0.813
# 0
# 20
# 40
# 60
# 80
